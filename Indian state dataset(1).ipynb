# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data[1].csv')

# %%
df
# Out:
#            State Name                                           Geometry  \
# 0   Arunachal Pradesh  POLYGON ((96.16260946675357 29.38078474502004,...
# 1               Assam  MULTIPOLYGON (((89.74322932956994 26.303620341...
# 2               Bihar  MULTIPOLYGON (((84.50719832504274 24.263231032...
# 3        Chhattisgarh  POLYGON ((83.33531747931829 24.09885072448139,...
# 4                 Goa  MULTIPOLYGON (((74.11917887850251 14.753440750...
# 5             Gujarat  MULTIPOLYGON (((71.70375251096965 20.999582290...
# 6             Haryana  POLYGON ((76.85065405474091 30.87511930631098,...
# 7    Himachal Pradesh  POLYGON ((76.79633817057015 33.25489599215638,...
# 8   Jammu and Kashmir  POLYGON ((74.73450654094415 37.02068299862157,...
# 9           Jharkhand  POLYGON ((87.60581887124397 25.31511789487502,...
# 10          Karnataka  MULTIPOLYGON (((74.69694054427077 13.327823363...
# 11             Kerala  POLYGON ((74.99575065337001 12.79226798218167,...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   State Name                        29 non-null     object
#  1   Geometry                          29 non-null     object
#  2   NSDP Per Capita (Nominal)1996-97  29 non-null     object
#  3   NSDP Per Capita (Nominal)2000-01  29 non-null     object
#  4   NSDP Per Capita (Nominal)2005-06  29 non-null     object
#  5   NSDP Per Capita (Nominal)2010-11  29 non-null     object
#  6   NSDP Per Capita (Nominal)2011-12  29 non-null     object
#  7   NSDP Per Capita (Nominal)2012-13  29 non-null     object
#  8   NSDP Per Capita (Nominal)2013-14  29 non-null     object
#  9   NSDP Per Capita (Nominal)2014-15  29 non-null     object
#  10  NSDP Per Capita (Nominal)2015-16  29 non-null     object
# ...

# %%
df.describe()
# Out:
#                State Name                                           Geometry  \
# count                  29                                                 29
# unique                 29                                                 29
# top     Arunachal Pradesh  POLYGON ((96.16260946675357 29.38078474502004,...
# freq                    1                                                  1
#
#        NSDP Per Capita (Nominal)1996-97 NSDP Per Capita (Nominal)2000-01  \
# count                                29                               29
# unique                               28                               28
# top                            ₹ 11,202                         ₹ 17,195
# freq                                  2                                2
#
#        NSDP Per Capita (Nominal)2005-06 NSDP Per Capita (Nominal)2010-11  \
# count                                29                               29
# ...

# %%
df.isnull().sum()
# Out:
# State Name                          0
# Geometry                            0
# NSDP Per Capita (Nominal)1996-97    0
# NSDP Per Capita (Nominal)2000-01    0
# NSDP Per Capita (Nominal)2005-06    0
# NSDP Per Capita (Nominal)2010-11    0
# NSDP Per Capita (Nominal)2011-12    0
# NSDP Per Capita (Nominal)2012-13    0
# NSDP Per Capita (Nominal)2013-14    0
# NSDP Per Capita (Nominal)2014-15    0
# NSDP Per Capita (Nominal)2015-16    0
# NSDP Per Capita (Nominal)2016-17    0
# NSDP Per Capita (Nominal)2017-18    0
# NSDP Per Capita (Nominal)2018-19    0
# NSDP Per Capita (Nominal)2019-20    0
# Growth from 2000 to 2010            0
# Growth from 2010 to 2019            0
# dtype: int64

# %%
df['NSDP Per Capita (Nominal)1996-97'].str.replace('₹','')
# Out:
# 0      10,816
# 1       7,394
# 2       4,001
# 3       8,353
# 4      26,418
# 5      16,153
# 6      16,611
# 7      11,960
# 8       8,667
# 9       7,235
# 10     11,202
# 11     13,280
# 12      8,819
# 13     17,844
# 14      7,920
# 15      9,243
# 16     12,210
# 17     11,805
# 18     17,353
# 19     10,102
# 20     11,332
# 21     11,670
# 22     13,269
# 23      8,109
# 24      7,476
# 25      9,334
# 26      9,857
# 27      6,548
# 28     11,202
# Name: NSDP Per Capita (Nominal)1996-97, dtype: object

# %%
df
# Out:
#            State Name                                           Geometry  \
# 0   Arunachal Pradesh  POLYGON ((96.16260946675357 29.38078474502004,...
# 1               Assam  MULTIPOLYGON (((89.74322932956994 26.303620341...
# 2               Bihar  MULTIPOLYGON (((84.50719832504274 24.263231032...
# 3        Chhattisgarh  POLYGON ((83.33531747931829 24.09885072448139,...
# 4                 Goa  MULTIPOLYGON (((74.11917887850251 14.753440750...
# 5             Gujarat  MULTIPOLYGON (((71.70375251096965 20.999582290...
# 6             Haryana  POLYGON ((76.85065405474091 30.87511930631098,...
# 7    Himachal Pradesh  POLYGON ((76.79633817057015 33.25489599215638,...
# 8   Jammu and Kashmir  POLYGON ((74.73450654094415 37.02068299862157,...
# 9           Jharkhand  POLYGON ((87.60581887124397 25.31511789487502,...
# 10          Karnataka  MULTIPOLYGON (((74.69694054427077 13.327823363...
# 11             Kerala  POLYGON ((74.99575065337001 12.79226798218167,...
# ...

# %%
df1=df

# %%
for i in df.select_dtypes(include="object").columns:
    df1[i]=df1[i].str.replace('₹','')
    df1[i]=df1[i].str.replace(',','')

# %%
df1
# Out:
#            State Name                                           Geometry  \
# 0   Arunachal Pradesh  POLYGON ((96.16260946675357 29.38078474502004 ...
# 1               Assam  MULTIPOLYGON (((89.74322932956994 26.303620341...
# 2               Bihar  MULTIPOLYGON (((84.50719832504274 24.263231032...
# 3        Chhattisgarh  POLYGON ((83.33531747931829 24.09885072448139 ...
# 4                 Goa  MULTIPOLYGON (((74.11917887850251 14.753440750...
# 5             Gujarat  MULTIPOLYGON (((71.70375251096965 20.999582290...
# 6             Haryana  POLYGON ((76.85065405474091 30.87511930631098 ...
# 7    Himachal Pradesh  POLYGON ((76.79633817057015 33.25489599215638 ...
# 8   Jammu and Kashmir  POLYGON ((74.73450654094415 37.02068299862157 ...
# 9           Jharkhand  POLYGON ((87.60581887124397 25.31511789487502 ...
# 10          Karnataka  MULTIPOLYGON (((74.69694054427077 13.327823363...
# 11             Kerala  POLYGON ((74.99575065337001 12.79226798218167 ...
# ...

# %%
df
# Out:
#            State Name                                           Geometry  \
# 0   Arunachal Pradesh  POLYGON ((96.16260946675357 29.38078474502004,...
# 1               Assam  MULTIPOLYGON (((89.74322932956994 26.303620341...
# 2               Bihar  MULTIPOLYGON (((84.50719832504274 24.263231032...
# 3        Chhattisgarh  POLYGON ((83.33531747931829 24.09885072448139,...
# 4                 Goa  MULTIPOLYGON (((74.11917887850251 14.753440750...
# 5             Gujarat  MULTIPOLYGON (((71.70375251096965 20.999582290...
# 6             Haryana  POLYGON ((76.85065405474091 30.87511930631098,...
# 7    Himachal Pradesh  POLYGON ((76.79633817057015 33.25489599215638,...
# 8   Jammu and Kashmir  POLYGON ((74.73450654094415 37.02068299862157,...
# 9           Jharkhand  POLYGON ((87.60581887124397 25.31511789487502,...
# 10          Karnataka  MULTIPOLYGON (((74.69694054427077 13.327823363...
# 11             Kerala  POLYGON ((74.99575065337001 12.79226798218167,...
# ...

# %%
df.columns
# Out:
# Index(['State Name', 'Geometry', 'NSDP Per Capita (Nominal)1996-97',
#        'NSDP Per Capita (Nominal)2000-01', 'NSDP Per Capita (Nominal)2005-06',
#        'NSDP Per Capita (Nominal)2010-11', 'NSDP Per Capita (Nominal)2011-12',
#        'NSDP Per Capita (Nominal)2012-13', 'NSDP Per Capita (Nominal)2013-14',
#        'NSDP Per Capita (Nominal)2014-15', 'NSDP Per Capita (Nominal)2015-16',
#        'NSDP Per Capita (Nominal)2016-17', 'NSDP Per Capita (Nominal)2017-18',
#        'NSDP Per Capita (Nominal)2018-19', 'NSDP Per Capita (Nominal)2019-20',
#        'Growth from 2000 to 2010', 'Growth from 2010 to 2019'],
#       dtype='object')

# %%
df
# Out:
#            State Name                                           Geometry  \
# 0   Arunachal Pradesh  POLYGON ((96.16260946675357 29.38078474502004,...
# 1               Assam  MULTIPOLYGON (((89.74322932956994 26.303620341...
# 2               Bihar  MULTIPOLYGON (((84.50719832504274 24.263231032...
# 3        Chhattisgarh  POLYGON ((83.33531747931829 24.09885072448139,...
# 4                 Goa  MULTIPOLYGON (((74.11917887850251 14.753440750...
# 5             Gujarat  MULTIPOLYGON (((71.70375251096965 20.999582290...
# 6             Haryana  POLYGON ((76.85065405474091 30.87511930631098,...
# 7    Himachal Pradesh  POLYGON ((76.79633817057015 33.25489599215638,...
# 8   Jammu and Kashmir  POLYGON ((74.73450654094415 37.02068299862157,...
# 9           Jharkhand  POLYGON ((87.60581887124397 25.31511789487502,...
# 10          Karnataka  MULTIPOLYGON (((74.69694054427077 13.327823363...
# 11             Kerala  POLYGON ((74.99575065337001 12.79226798218167,...
# ...

# %%
df1.isnull().sum()
# Out:
# State Name                          0
# Geometry                            0
# NSDP Per Capita (Nominal)1996-97    0
# NSDP Per Capita (Nominal)2000-01    0
# NSDP Per Capita (Nominal)2005-06    0
# NSDP Per Capita (Nominal)2010-11    0
# NSDP Per Capita (Nominal)2011-12    0
# NSDP Per Capita (Nominal)2012-13    0
# NSDP Per Capita (Nominal)2013-14    0
# NSDP Per Capita (Nominal)2014-15    0
# NSDP Per Capita (Nominal)2015-16    0
# NSDP Per Capita (Nominal)2016-17    0
# NSDP Per Capita (Nominal)2017-18    0
# NSDP Per Capita (Nominal)2018-19    0
# NSDP Per Capita (Nominal)2019-20    0
# Growth from 2000 to 2010            0
# Growth from 2010 to 2019            0
# dtype: int64

# %%
df.dtypes
# Out:
# State Name                          object
# Geometry                            object
# NSDP Per Capita (Nominal)1996-97    object
# NSDP Per Capita (Nominal)2000-01    object
# NSDP Per Capita (Nominal)2005-06    object
# NSDP Per Capita (Nominal)2010-11    object
# NSDP Per Capita (Nominal)2011-12    object
# NSDP Per Capita (Nominal)2012-13    object
# NSDP Per Capita (Nominal)2013-14    object
# NSDP Per Capita (Nominal)2014-15    object
# NSDP Per Capita (Nominal)2015-16    object
# NSDP Per Capita (Nominal)2016-17    object
# NSDP Per Capita (Nominal)2017-18    object
# NSDP Per Capita (Nominal)2018-19    object
# NSDP Per Capita (Nominal)2019-20    object
# Growth from 2000 to 2010            object
# Growth from 2010 to 2019            object
# dtype: object

# %%
for i in ['NSDP Per Capita (Nominal)1996-97','NSDP Per Capita (Nominal)2000-01', 'NSDP Per Capita (Nominal)2005-06',
       'NSDP Per Capita (Nominal)2010-11', 'NSDP Per Capita (Nominal)2011-12',
       'NSDP Per Capita (Nominal)2012-13', 'NSDP Per Capita (Nominal)2013-14',
       'NSDP Per Capita (Nominal)2014-15', 'NSDP Per Capita (Nominal)2015-16',
       'NSDP Per Capita (Nominal)2016-17', 'NSDP Per Capita (Nominal)2017-18',
       'NSDP Per Capita (Nominal)2018-19', 'NSDP Per Capita (Nominal)2019-20']:
    df1[i]=df1[i].astype(float)

# %%
df1
# Out:
#            State Name                                           Geometry  \
# 0   Arunachal Pradesh  POLYGON ((96.16260946675357 29.38078474502004 ...
# 1               Assam  MULTIPOLYGON (((89.74322932956994 26.303620341...
# 2               Bihar  MULTIPOLYGON (((84.50719832504274 24.263231032...
# 3        Chhattisgarh  POLYGON ((83.33531747931829 24.09885072448139 ...
# 4                 Goa  MULTIPOLYGON (((74.11917887850251 14.753440750...
# 5             Gujarat  MULTIPOLYGON (((71.70375251096965 20.999582290...
# 6             Haryana  POLYGON ((76.85065405474091 30.87511930631098 ...
# 7    Himachal Pradesh  POLYGON ((76.79633817057015 33.25489599215638 ...
# 8   Jammu and Kashmir  POLYGON ((74.73450654094415 37.02068299862157 ...
# 9           Jharkhand  POLYGON ((87.60581887124397 25.31511789487502 ...
# 10          Karnataka  MULTIPOLYGON (((74.69694054427077 13.327823363...
# 11             Kerala  POLYGON ((74.99575065337001 12.79226798218167 ...
# ...

# %%
df1.dtypes
# Out:
# State Name                           object
# Geometry                             object
# NSDP Per Capita (Nominal)1996-97    float64
# NSDP Per Capita (Nominal)2000-01    float64
# NSDP Per Capita (Nominal)2005-06    float64
# NSDP Per Capita (Nominal)2010-11    float64
# NSDP Per Capita (Nominal)2011-12    float64
# NSDP Per Capita (Nominal)2012-13    float64
# NSDP Per Capita (Nominal)2013-14    float64
# NSDP Per Capita (Nominal)2014-15    float64
# NSDP Per Capita (Nominal)2015-16    float64
# NSDP Per Capita (Nominal)2016-17    float64
# NSDP Per Capita (Nominal)2017-18    float64
# NSDP Per Capita (Nominal)2018-19    float64
# NSDP Per Capita (Nominal)2019-20    float64
# Growth from 2000 to 2010             object
# Growth from 2010 to 2019             object
# dtype: object

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
for i in df1.select_dtypes(include="number").columns:
    plt.figure(figsize=(20,12))
    sns.countplot(data=df1,x=i)
    plt.show()

# %%
for i in df1.select_dtypes(include="number").columns:
    plt.figure(figsize=(20,12))
    plt.xticks(rotation=90)
    sns.barplot(data=df1,y=i,x=df['State Name'])
    plt.show()

# %%
sns.heatmap(df1.select_dtypes(include="number").corr(),annot=True)
# Out:
# <Axes: >

# %%
df1.select_dtypes(include="number")
# Out:
#     NSDP Per Capita (Nominal)1996-97  NSDP Per Capita (Nominal)2000-01  \
# 0                            10816.0                           15260.0
# 1                             7394.0                           12803.0
# 2                             4001.0                            6415.0
# 3                             8353.0                           10744.0
# 4                            26418.0                           43735.0
# 5                            16153.0                           18392.0
# 6                            16611.0                           25583.0
# 7                            11960.0                           22795.0
# 8                             8667.0                           14268.0
# 9                             7235.0                           10345.0
# 10                           11202.0                           17195.0
# 11                           13280.0                           20094.0
# ...

# %%
for i in df1.select_dtypes(include="number").columns:
    plt.figure(figsize=(20,12))
    sns.boxplot(data=df1,x=i)
    plt.show()
